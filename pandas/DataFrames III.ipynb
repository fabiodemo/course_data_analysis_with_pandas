# %% [markdown]
# # Dataframes III

# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)

# %% [markdown]
# ## The set_index and reset_index Methods

# %%
#bond = pd.read_csv("jamesbond.csv", index_col='Film')
bond = pd.read_csv("jamesbond.csv")
bond.head(3)

# %%
bond.set_index('Film', inplace=True)

# %%
bond

# %% [markdown]
# Go back to old standard index

# %%
bond.reset_index(drop = False) #DON'T DROP THE COLUMN THAT WAS USED AS INDEX (default version)
bond.reset_index(drop = True) #If we want to drop the column, we set to True
bond.reset_index(drop = False)

# %%
bond.head(3)

# %%
bond.reset_index(inplace=True)
bond.set_index('Year', inplace=True)

# %%
bond.head(3)

# %% [markdown]
# ## Retrieve Rows by Index Label with .loc[] Acessor

# %% [markdown]
# It's easier for pandas to find an item on a sorted collection than in a random collection.

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)

# %%
bond.loc['A View to a Kill']
bond.loc['Goldfinger']
bond.loc['GoldenEye']

# %% [markdown]
# Looking for something that doesn't exist

# %%
#bond.loc["Sacred Bond"]

# %% [markdown]
# When Looking for duplicated rows, an dataframe will be returned

# %%
bond.loc["Casino Royale"]

# %% [markdown]
# Extract from one value to another

# %%
bond.loc["Diamonds Are Forever":"From Russia with Love"]

# %%
bond.loc["Diamonds Are Forever":"From Russia with Love":2] # With skipping n (2 in this case) numbers of rows

# %% [markdown]
# Until the end of dataframe

# %%
bond.loc["GoldenEye":]

# %% [markdown]
# From the beginning of the dataframe, until what we want

# %%
bond.loc[:"On Her Majesty's Secret Service"]

# %%
bond.loc[["Die Another Day", "Octopussy"]]

# %% [markdown]
# Every value passed on a list like this, MUST exist (otherwise we will get an error)

# %%
bond.loc[["Octopussy", "Die Another Day"]]

# %% [markdown]
# So we should test if this value exist before retrieve it

# %%
"Gold Bond" in bond.index

# %%
"Octopussy" in bond.index

# %% [markdown]
# ## Retrieve Rows by Index Position with iloc Acessor

# %% [markdown]
# iloc -> index location

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)

# %%
bond.iloc[0]
bond.iloc[15]
bond.iloc[[15,20]]

# %% [markdown]
# We will get an error if try to access an unexistent index

# %%
#bond.iloc[1000]

# %%
bond.iloc[3:8]
# Out:
#                               Film  Year           Actor       Director  \
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond.iloc[20:]
bond.iloc[:4]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.set_index("Film", inplace=True)

# %%
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["GoldenEye"]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %% [markdown]
# Even when having a new index based on a string, we still will have a position index

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[[5,10,14]]
# Out:
#                  Year           Actor       Director  Box Office  Budget  \
# Film
# Dr. No           1962    Sean Connery  Terence Young       448.8     7.0
# Licence to Kill  1989  Timothy Dalton      John Glen       250.9    56.7
# Octopussy        1983     Roger Moore      John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Dr. No                         0.6
# Licence to Kill                7.9
# Octopussy                      7.8

# %% [markdown]
# ## Second Arguments to loc and iloc Acessors

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Moonraker", "Actor"]
bond.loc["Moonraker", "Director"]
bond.loc["Moonraker", ["Director", "Box Office"]]
bond.loc[["Casino Royale", "Moonraker"], ["Director", "Box Office"]]
# Out:
#                       Director  Box Office
# Film
# Casino Royale  Martin Campbell       581.5
# Casino Royale       Ken Hughes       315.0
# Moonraker        Lewis Gilbert       535.0

# %% [markdown]
# Slicing dataframe with loc

# %%
bond.loc["Moonraker", "Director":"Budget"]
bond.loc["Moonraker":"Thunderball", "Director":"Budget"]
bond.loc["Moonraker":, "Director":"Budget"]
bond.loc[:"Moonraker", "Box Office":]
# Out:
#                        Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill            275.2    54.5                9.1
# Casino Royale               581.5   145.3                3.3
# Casino Royale               315.0    85.0                NaN
# Diamonds Are Forever        442.5    34.7                5.8
# Die Another Day             465.4   154.2               17.9
# Dr. No                      448.8     7.0                0.6
# For Your Eyes Only          449.4    60.2                NaN
# From Russia with Love       543.8    12.6                1.6
# GoldenEye                   518.5    76.9                5.1
# Goldfinger                  820.4    18.6                3.2
# Licence to Kill             250.9    56.7                7.9
# Live and Let Die            460.3    30.8                NaN
# Moonraker                   535.0    91.5                NaN

# %%
bond.iloc[14]
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
#bond.iloc[row,column]
bond.iloc[14,2:5]
bond.iloc[[14, 17],2:5]
bond.iloc[[14, 17],[2, 5]]
bond.iloc[:7,:3]
# Out:
#                       Year           Actor         Director
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
# Dr. No                1962    Sean Connery    Terence Young
# For Your Eyes Only    1981     Roger Moore        John Glen

# %% [markdown]
# ## Set New Value for a Specific Cell

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Overwriting a cell value

# %%
bond.loc["Dr. No", "Actor"] = "Sir Sean Connery"

# %%
bond.loc["Dr. No"]
bond.loc["Dr. No", "Actor"]
# Out:
# 'Sir Sean Connery'

# %% [markdown]
# Overwriting multiple cells

# %%
bond.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = [4480000000, 700000000, 60000000]

# %%
bond.loc["Dr. No"]
# Out:
# Year                             1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Box Office               4480000000.0
# Budget                    700000000.0
# Bond Actor Salary          60000000.0
# Name: Dr. No, dtype: object

# %% [markdown]
# ## Set Multiple Values in DataFrame

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
actor_is_sean_connery = bond.Actor == "Sean Connery"

# %% [markdown]
# Error that can't happen: \
# A value is trying to be set on a copy of a slice from a DataFrame.\
# Try using .loc[row_indexer,col_indexer] = value instead

# %%
#bond[actor_is_sean_connery]["Actor"] = "Sir Sean Connery"

# %% [markdown]
# Method that should be used:

# %%
bond.loc[actor_is_sean_connery, "Actor"] = "Sir Sean Connery"

# %%
bond.loc[actor_is_sean_connery]
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Rename the cell value using a mapper (fed with a dictionary)

# %%
bond.rename(mapper={"GoldenEye": "Golden Eye", "The World Is Not Enough": "Best Bond Movie Ever"}, axis = 0)
bond.rename(mapper={"GoldenEye": "Golden Eye", "The World Is Not Enough": "Best Bond Movie Ever"}, axis = "rows")
bond.rename(mapper={"GoldenEye": "Golden Eye", "The World Is Not Enough": "Best Bond Movie Ever"}, axis = "index")
bond.rename(index={"GoldenEye": "Golden Eye", "The World Is Not Enough": "Best Bond Movie Ever"}, inplace=True)

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# Rename Columns

# %%
bond.head(1)
# Out:
#                   Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.rename(mapper={"Year" : "Release Date", "Box Office": "Revenue"}, axis = 1)
bond.rename(mapper={"Year" : "Release Date", "Box Office": "Revenue"}, axis = "columns")
bond.rename(columns={"Year" : "Release Date", "Box Office": "Revenue"}, inplace=True)

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %% [markdown]
# Rename all columns at the same command

# %%
bond.columns = ['Year of Release', 'Actor', 'Director', 'Gross', 'Cost', 'Actor Salary']

# %%
bond.head(1)
# Out:
#                   Year of Release        Actor   Director  Gross  Cost  \
# Film
# A View to a Kill             1985  Roger Moore  John Glen  275.2  54.5
#
#                   Actor Salary
# Film
# A View to a Kill           9.1

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Use drop

# %%
bond.drop("A View to a Kill")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.drop("Casino Royale", inplace=True)

# %% [markdown]
# Dropping entire column

# %%
bond.drop("Box Office", axis=1)
bond.drop("Box Office", axis="columns")
bond.drop(["Box Office", "Budget", "Bond Actor Salary"], axis="columns",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\F8394~1.ROS\AppData\Local\Temp/ipykernel_6320/1600346100.py in <module>
# ----> 1 bond.drop("Box Office", axis=1)
#       2 bond.drop("Box Office", axis="columns")
#       3 bond.drop(["Box Office", "Budget", "Bond Actor Salary"], axis="columns",inplace=True)
#       4 bond
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# Popping and storing the popped data as a series

# %%
actor = bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %% [markdown]
# Deleting a column from dataframe with "del"

# %%
del bond["Director"]
del bond["Year"]

# %%
bond
# Out:
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# ...

# %% [markdown]
# ## Create Random Sample

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample()
# Out:
#                Year        Actor    Director  Box Office  Budget  \
# Film
# Casino Royale  1967  David Niven  Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN

# %%
bond.sample(n=4)
bond.sample(frac = .25) # 25% of the dataframe
# Out:
#                                  Year           Actor         Director  \
# Film
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore    Lewis Gilbert
# Quantum of Solace                2008    Daniel Craig     Marc Forster
# Octopussy                        1983     Roger Moore        John Glen
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Diamonds Are Forever                  442.5    34.7                5.8
# The Spy Who Loved Me                  533.0    45.1                NaN
# Quantum of Solace                     514.2   181.4                8.1
# ...

# %% [markdown]
# Random columns

# %%
bond.sample(n=2, axis="columns")
# Out:
#                                  Bond Actor Salary            Director
# Film
# A View to a Kill                               9.1           John Glen
# Casino Royale                                  3.3     Martin Campbell
# Casino Royale                                  NaN          Ken Hughes
# Diamonds Are Forever                           5.8        Guy Hamilton
# Die Another Day                               17.9        Lee Tamahori
# Dr. No                                         0.6       Terence Young
# For Your Eyes Only                             NaN           John Glen
# From Russia with Love                          1.6       Terence Young
# GoldenEye                                      5.1     Martin Campbell
# Goldfinger                                     3.2        Guy Hamilton
# Licence to Kill                                7.9           John Glen
# Live and Let Die                               NaN        Guy Hamilton
# ...

# %% [markdown]
# ## The .nsmallets() and .nlargest() Methods

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sort_values("Box Office", ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(n=3, columns="Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(n=3, columns="Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.nlargest(3, "Budget")
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nsmallest(6, "Bond Actor Salary")
# Out:
#                                  Year           Actor         Director  \
# Film
# Dr. No                           1962    Sean Connery    Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# From Russia with Love            1963    Sean Connery    Terence Young
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# You Only Live Twice              1967    Sean Connery    Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Casino Royale                         581.5   145.3                3.3
# ...

# %%
bond["Box Office"].nlargest(8)
# Out:
# Film
# Skyfall                  943.5
# Thunderball              848.1
# Goldfinger               820.4
# Spectre                  726.7
# Casino Royale            581.5
# From Russia with Love    543.8
# Moonraker                535.0
# The Spy Who Loved Me     533.0
# Name: Box Office, dtype: float64

# %%
bond.Year.nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %% [markdown]
# ## Filtering with the where Method

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# All the rows without Sean Connery as an actor will return as NaN, EXCEPT the Index (in this case: Film)

# %%
mask = bond.Actor == "Sean Connery"
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
bond.where(bond["Box Office"] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask2 = bond["Box Office"] > 800

# %%
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %% [markdown]
# ## The .query() Method
# Only works when we don't have space between each of the column names

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]

# %%
bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %% [markdown]
# Accepts regular comparisons \
# The mix between single and double quotes must be present no matter its order, what is necessary is that we alternate between the two types of quotes.

# %%
bond.query('Actor == "Sean Connery"')
bond.query("Director == 'Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %% [markdown]
# Multiple comparisons will use the word instead of the comparison symbols (Same as python)

# %%
bond.query("Actor == 'Roger Moore' and Director == 'John Glen'")
bond.query("Actor == 'Roger Moore' or Director == 'John Glen'")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %%
bond.query("Actor in ['Timothy Dalton','George Lazenby']")
bond.query("Actor not in ['Timothy Dalton','George Lazenby']")
# Out:
#                              Year           Actor            Director  \
# Film
# A View to a Kill             1985     Roger Moore           John Glen
# Casino Royale                2006    Daniel Craig     Martin Campbell
# Casino Royale                1967     David Niven          Ken Hughes
# Diamonds Are Forever         1971    Sean Connery        Guy Hamilton
# Die Another Day              2002  Pierce Brosnan        Lee Tamahori
# Dr. No                       1962    Sean Connery       Terence Young
# For Your Eyes Only           1981     Roger Moore           John Glen
# From Russia with Love        1963    Sean Connery       Terence Young
# GoldenEye                    1995  Pierce Brosnan     Martin Campbell
# Goldfinger                   1964    Sean Connery        Guy Hamilton
# Live and Let Die             1973     Roger Moore        Guy Hamilton
# Moonraker                    1979     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ## A Review of the .apply() Method on Single Columns

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

bond["Box Office"] = bond["Box Office"].apply(convert_to_string_and_add_millions)

# %%
bond["Box Office"]
# Out:
# Film
# A View to a Kill                   275.2 MILLIONS!
# Casino Royale                      581.5 MILLIONS!
# Casino Royale                      315.0 MILLIONS!
# Diamonds Are Forever               442.5 MILLIONS!
# Die Another Day                    465.4 MILLIONS!
# Dr. No                             448.8 MILLIONS!
# For Your Eyes Only                 449.4 MILLIONS!
# From Russia with Love              543.8 MILLIONS!
# GoldenEye                          518.5 MILLIONS!
# Goldfinger                         820.4 MILLIONS!
# Licence to Kill                    250.9 MILLIONS!
# Live and Let Die                   460.3 MILLIONS!
# Moonraker                          535.0 MILLIONS!
# Never Say Never Again              380.0 MILLIONS!
# Octopussy                          373.8 MILLIONS!
# On Her Majesty's Secret Service    291.5 MILLIONS!
# Quantum of Solace                  514.2 MILLIONS!
# Skyfall                            943.5 MILLIONS!
# ...

# %%
bond.Budget = bond.Budget.apply(convert_to_string_and_add_millions)

# %% [markdown]
# Doing the same things, but instead of each at time, doing all the three columns at the same time

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
bond.head(5)
# Out:
#                       Year           Actor         Director  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
#
#                                      Box Office           Budget  \
# Film
# A View to a Kill      275.2 MILLIONS! MILLIONS!   54.5 MILLIONS!
# Casino Royale         581.5 MILLIONS! MILLIONS!  145.3 MILLIONS!
# Casino Royale         315.0 MILLIONS! MILLIONS!   85.0 MILLIONS!
# Diamonds Are Forever  442.5 MILLIONS! MILLIONS!   34.7 MILLIONS!
# Die Another Day       465.4 MILLIONS! MILLIONS!  154.2 MILLIONS!
#
#                      Bond Actor Salary
# Film
# A View to a Kill         9.1 MILLIONS!
# Casino Royale            3.3 MILLIONS!
# Casino Royale            nan MILLIONS!
# ...

# %% [markdown]
# ## The .apply() Method with Row Values

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]

    if actor == "Pierce Brosnan":
        return "The best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"

# Apply horizontally (column wide)
bond.apply(good_movie, axis="columns")
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# ...

# %% [markdown]
# ## The .copy() Method

# %% [markdown]
# Store a copy of a series or dataframe in a different memory position

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond.Director
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %% [markdown]
# ERROR: A value is trying to be set on a copy of a slice from a DataFrame

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# C:\Users\F8394~1.ROS\AppData\Local\Temp/ipykernel_6320/2347769033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors["A View to a Kill"] = "Mister John Glen"

# %% [markdown]
# In case we just wanted to change OUR COPY to work with it, we can do it using .copy()

# %%
bond = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %% [markdown]
# Perhaps we wanted to modify the original values to be different

# %%
directors = bond.Director.copy()
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
