# %% [markdown]
# # DataFrames II: Filtering Data
# df = convention for calling a dataframe while coding. Use only when working with one set of data (be more explicit).

# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")
df

# %%
df.info()
# To pandas, strings are considered objects

# %%
df["Start Date"].head(2)

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Start Date"].head(3)

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Last Login Time"].head(3)

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head(3)

# %%
df["Gender"]

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df.info()

# %%
#Total that was reduced by converting the data type
100 - (49 / 62.6) * 100

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %% [markdown]
# ## Filter a DataFrame Based on a Condition

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %% [markdown]
# The code below will filter the dataframe based on the gender, returning every row that has the gender equal to "Male"

# %%
df[df["Gender"] == "Male"]

# %%
mask = df["Team"] == "Finance"
df[mask]

# %%
mask = df["Senior Management"]
df[mask]

# %%
mask = df["Team"] != "Marketing"
df[mask]

# %%
mask = df["Salary"] > 131930
df[mask]

# %%
df[df["Bonus %"] < 1.5]

# %%
Filtering by date

# %%
mask = df["Start Date"] <= "1985-01-01"
df[mask]

# %% [markdown]
# ## Filter with More than One Condition (AND - &)

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %%
mask1 = df["Gender"] == "Male"

mask2 = df["Team"] == "Marketing"

df[mask1 & mask2]

# %% [markdown]
# ## Filter with More than One Condition (OR - |)

# %%
mask1 = df["Senior Management"] ==  False
mask2 = df["Start Date"] < "1990-01-01"
df[mask1 | mask2]

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Service"
mask3 = df["Start Date"] >= "2016-06-01"
df[(mask1 & mask) | mask3]

# %% [markdown]
# ## The .isin() Method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3]

# %%
mask = df.Team.isin(["Legal", "Product", "Marketing"])
df[mask]

# %% [markdown]
# ## The .isnull() and .notnull() Methods

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %%
df["Team"].isnull()

# %%
df[df["Team"].isnull()]

# %%
df.Gender.notnull()

# %%
mask = df["Gender"].notnull()
df[mask]

# %% [markdown]
# ## The .between() Method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)

# %%
mask = df.Salary.between(6000, 70000)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-02-14 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-02-14 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2022-02-14 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-02-14 09:01:00   63241   15.132
# 14    Kimberly  Female 1999-01-14 2022-02-14 07:13:00   41426   14.543
# ..         ...     ...        ...                 ...     ...      ...
# 988      Alice  Female 2004-10-05 2022-02-14 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 2022-02-14 16:58:00   38344    3.794
# 552    Barbara  Female 1991-09-02 2022-02-14 15:41:00  127297   11.905
# 603       Carl     NaN 1991-10-26 2022-02-14 08:11:00  100888   12.490
# 639     Amanda     NaN 1991-08-11 2022-02-14 14:15:00   46665   19.391
# 704     Thomas    Male 1991-09-07 2022-02-14 09:51:00   65251   11.211
# 725     Jeremy    Male 1991-05-19 2022-02-14 13:40:00  131513    1.876
# 766     Justin    Male 1991-07-25 2022-02-14 00:45:00  112975    9.699
# 771      Peter    Male 1991-05-22 2022-02-14 01:39:00  102577   12.026
# 783        NaN     NaN 1991-04-15 2022-02-14 03:39:00  132505   13.592
# 891    Timothy    Male 1991-08-25 2022-02-14 10:37:00   92587    8.475
# 895     Janice     NaN 1991-11-19 2022-02-14 18:02:00  139791   16.968
# 909     Donald    Male 1991-08-01 2022-02-14 02:25:00   61999    6.466
# 923      Irene     NaN 1991-02-28 2022-02-14 22:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10 2022-02-14 16:58:00   38344    3.794
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               True                 Legal
# 148               True                 Sales
# 166               True                 Sales
# 172              False               Finance
# 220               True             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               True               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal

# %%
df[df["Last Login Time"].between("08:30AM", "12:00PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-02-14 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2022-02-14 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-02-14 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2022-02-14 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2022-02-14 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2022-02-14 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2022-02-14 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2022-02-14 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2022-02-14 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2022-02-14 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# 7                 True               Finance
# 10                True                   NaN
# 18               False       Client Services
# 33               False  Business Development
# ..                 ...                   ...
# 963               True                 Sales
# 977              False               Product
# 982               True       Human Resources
# 988              False       Human Resources
# 992               True               Finance
#
# [136 rows x 8 columns]

# %% [markdown]
# ## The .duplicated() Method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-14 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-02-14 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-02-14 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df[df["First Name"].duplicated()]
df["First Name"].duplicated(keep = "last") # Keep the last duplicated value
df[df["First Name"].duplicated(keep = False)] # False will mark something to duplicate if happens more than once
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-02-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-02-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-02-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-02-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-02-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-02-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-02-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-02-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-02-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# The negation mark (~) will make all false value as trues and true as false, returning only the first names that happened once

# %%
df[~df["First Name"].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-02-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-02-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-02-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-02-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-02-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-02-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-02-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-02-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-02-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ## The .drop_duplicates() Method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-14 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-02-14 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-02-14 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %% [markdown]
# In this dataframe, there are no rows with all columns exactly the same, so the lenght will be the same

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %% [markdown]
# So then, we need to provide some other parameters

# %%
len(df.drop_duplicates(subset=["First Name"], keep="first"))
 # Will only look for first name column, and will keep the first occurence of the repetead values or the values that happened only once
df.drop_duplicates(subset=["First Name"], keep="first")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-02-14 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-02-14 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-02-14 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-02-14 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-02-14 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-02-14 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-02-14 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-02-14 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-02-14 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-02-14 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# 137              False     Distribution
# 300               True      Engineering
# 372               True      Engineering
# 988              False  Human Resources
# ..                 ...              ...
# 433               True            Legal
# 177               True     Distribution
# 820               True  Human Resources
# 450              False            Legal
# 7                 True          Finance
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(subset=["First Name"], keep=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-02-14 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-02-14 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-02-14 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-02-14 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-02-14 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-02-14 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-02-14 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-02-14 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-02-14 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# In the case below, we got an empty dataframe because every team repeat more than once

# %%
df.drop_duplicates(subset=["Team"], keep=False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %% [markdown]
# Only if both values (AND) are repetead

# %%
df.drop_duplicates(subset=["First Name", "Team"], inplace=True)
df.head(4)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-14 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2022-02-14 14:53:00   52119   11.343
# 137       Adam   Male 2011-05-21 2022-02-14 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2022-02-14 20:57:00  110194   14.727
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product

# %%
len(df)
# Out:
# 769

# %% [markdown]
# ## The .unique() and .nunique() Mehtods

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-14 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-14 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-14 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
len(df.Team.unique())
# Out:
# 11

# %%
df.Team.nunique() # doesnt include NaN
df.Team.nunique(dropna=False) # dropna will not drop the NaN from the results
# Out:
# 11
